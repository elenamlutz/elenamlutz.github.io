# %%
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
alt.data_transformers.disable_max_rows()
matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline

# %%
import altair as alt
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
# What are the places that people most frequently overdose (residences, motels, parks, streets)? 
# How does Connecticut’s prescription tendencies compare to the national average?
# How many actually die the hospital? How many don't reach the hospital?
# How to deal with cocktail of drugs data?

# %%
df = pd.read_csv("Accidental_Drug_Related_Deaths_2012-2018.csv")

# %%
df.head()
# Out:
#         ID          Date      DateType   Age     Sex          Race  \
# 0  14-0273  6/28/14 0:00  DateReported   NaN     NaN           NaN
# 1  13-0102  3/21/13 0:00   DateofDeath  48.0    Male         Black
# 2  16-0165  3/13/16 0:00   DateofDeath  30.0  Female         White
# 3  16-0208  3/31/16 0:00   DateofDeath  23.0    Male         White
# 4  13-0052  2/13/13 0:00   DateofDeath  22.0    Male  Asian, Other
#
#   ResidenceCity ResidenceCounty ResidenceState  DeathCity  ... Tramad  \
# 0           NaN             NaN            NaN        NaN  ...    NaN
# 1       NORWALK             NaN            NaN    NORWALK  ...    NaN
# 2    SANDY HOOK       FAIRFIELD             CT    DANBURY  ...    NaN
# 3           RYE     WESTCHESTER             NY  GREENWICH  ...    NaN
# 4      FLUSHING          QUEENS            NaN  GREENWICH  ...    NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# 0                NaN           NaN   NaN       NaN       NaN      Accident
# 1                NaN           NaN   NaN       NaN       NaN      Accident
# 2                NaN           NaN   NaN       NaN         Y      Accident
# 3                NaN           NaN   NaN       NaN         Y      Accident
# 4                NaN           NaN   NaN       NaN       NaN      Accident
#
#                              DeathCityGeo  \
# 0             CT\n(41.575155, -72.738288)
# 1     Norwalk, CT\n(41.11805, -73.412906)
# 2    Danbury, CT\n(41.393666, -73.451539)
# 3  Greenwich, CT\n(41.026526, -73.628549)
# 4  Greenwich, CT\n(41.026526, -73.628549)
#
#                           ResidenceCityGeo                InjuryCityGeo
# 0              CT\n(41.575155, -72.738288)  CT\n(41.575155, -72.738288)
# 1      NORWALK, CT\n(41.11805, -73.412906)  CT\n(41.575155, -72.738288)
# 2  SANDY HOOK, CT\n(41.419998, -73.282501)                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN  CT\n(41.575155, -72.738288)
#
# [5 rows x 41 columns]

# %%
df = df.drop(['DateType', 'ResidenceCounty', 'ResidenceState', 'DeathCounty', 'InjuryCity', 'InjuryCounty', 'InjuryState', 'OtherSignifican', 'MannerofDeath'], axis=1)

# %%
df.head()
# Out:
#         ID          Date   Age     Sex          Race ResidenceCity  DeathCity  \
# 0  14-0273  6/28/14 0:00   NaN     NaN           NaN           NaN        NaN
# 1  13-0102  3/21/13 0:00  48.0    Male         Black       NORWALK    NORWALK
# 2  16-0165  3/13/16 0:00  30.0  Female         White    SANDY HOOK    DANBURY
# 3  16-0208  3/31/16 0:00  23.0    Male         White           RYE  GREENWICH
# 4  13-0052  2/13/13 0:00  22.0    Male  Asian, Other      FLUSHING  GREENWICH
#
#    Location LocationifOther     DescriptionofInjury  ... Amphet Tramad  \
# 0       NaN             NaN               substance  ...    NaN    NaN
# 1  Hospital             NaN                     NaN  ...    NaN    NaN
# 2  Hospital             NaN         Substance Abuse  ...    NaN    NaN
# 3  Hospital             NaN         substance abuse  ...    NaN    NaN
# 4  Hospital             NaN  Transdermal Absorption  ...    NaN    NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid  \
# 0                NaN           NaN   NaN       NaN       NaN
# 1                NaN           NaN   NaN       NaN       NaN
# 2                NaN           NaN   NaN       NaN         Y
# 3                NaN           NaN   NaN       NaN         Y
# 4                NaN           NaN   NaN       NaN       NaN
#
#                              DeathCityGeo  \
# 0             CT\n(41.575155, -72.738288)
# 1     Norwalk, CT\n(41.11805, -73.412906)
# 2    Danbury, CT\n(41.393666, -73.451539)
# 3  Greenwich, CT\n(41.026526, -73.628549)
# 4  Greenwich, CT\n(41.026526, -73.628549)
#
#                           ResidenceCityGeo                InjuryCityGeo
# 0              CT\n(41.575155, -72.738288)  CT\n(41.575155, -72.738288)
# 1      NORWALK, CT\n(41.11805, -73.412906)  CT\n(41.575155, -72.738288)
# 2  SANDY HOOK, CT\n(41.419998, -73.282501)                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN  CT\n(41.575155, -72.738288)
#
# [5 rows x 32 columns]

# %%
df.Date = df.Date.replace(r'\d\d/\d\d/','', regex=True)

# %%
df.Date =df.Date.replace(r'\d\d:.*', '', regex=True)

# %%
df_age = pd.DataFrame(df.groupby('Date').Age.value_counts())

# %%
df_age = pd.DataFrame(df.groupby('Date').Age.value_counts())

# %%
df_age=df_age.reset_index(level='Date')

# %%
df_age=df_age.rename(columns={'Age': 'agecount'})

# %%
df_age = df_age.reset_index()

# %%
df_age.head()
# Out:
#     Age         Date  agecount
# 0  35.0  1/1/12 0:00         1
# 1  50.0  1/1/13 0:00         1
# 2  25.0  1/1/15 0:00         1
# 3  29.0  1/1/15 0:00         1
# 4  69.0  1/1/15 0:00         1

# %%
df.Date = df.Date.astype(str)

# %%
df.Date = df.Date.str.strip()

# %%
df['Heroin'] = df.Heroin.replace({'Y': 'Heroin'})

# %%
df['Cocaine'] = df.Cocaine.replace({'Y': 'Cocaine'})

# %%
df['Fentanyl'] = df.Fentanyl.replace({'Y': 'Fentanyl'})

# %%
df['Ethanol'] = df.Ethanol.replace({'Y': 'Ethanol'})

# %%
df['Hydrocodone'] = df.Hydrocodone.replace({'Y': 'Hydrocodone'})

# %%
df['Benzodiazepine'] = df.Benzodiazepine.replace({'Y': 'Benzodiazepine'})

# %%
df['Methadone'] = df.Methadone.replace({'Y': 'Methadone'})

# %%
df.head()
# Out:
#         ID          Date   Age     Sex          Race ResidenceCity  DeathCity  \
# 0  14-0273  6/28/14 0:00   NaN     NaN           NaN           NaN        NaN
# 1  13-0102  3/21/13 0:00  48.0    Male         Black       NORWALK    NORWALK
# 2  16-0165  3/13/16 0:00  30.0  Female         White    SANDY HOOK    DANBURY
# 3  16-0208  3/31/16 0:00  23.0    Male         White           RYE  GREENWICH
# 4  13-0052  2/13/13 0:00  22.0    Male  Asian, Other      FLUSHING  GREENWICH
#
#    Location LocationifOther     DescriptionofInjury  ... Amphet Tramad  \
# 0       NaN             NaN               substance  ...    NaN    NaN
# 1  Hospital             NaN                     NaN  ...    NaN    NaN
# 2  Hospital             NaN         Substance Abuse  ...    NaN    NaN
# 3  Hospital             NaN         substance abuse  ...    NaN    NaN
# 4  Hospital             NaN  Transdermal Absorption  ...    NaN    NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid  \
# 0                NaN           NaN   NaN       NaN       NaN
# 1                NaN           NaN   NaN       NaN       NaN
# 2                NaN           NaN   NaN       NaN         Y
# 3                NaN           NaN   NaN       NaN         Y
# 4                NaN           NaN   NaN       NaN       NaN
#
#                              DeathCityGeo  \
# 0             CT\n(41.575155, -72.738288)
# 1     Norwalk, CT\n(41.11805, -73.412906)
# 2    Danbury, CT\n(41.393666, -73.451539)
# 3  Greenwich, CT\n(41.026526, -73.628549)
# 4  Greenwich, CT\n(41.026526, -73.628549)
#
#                           ResidenceCityGeo                InjuryCityGeo
# 0              CT\n(41.575155, -72.738288)  CT\n(41.575155, -72.738288)
# 1      NORWALK, CT\n(41.11805, -73.412906)  CT\n(41.575155, -72.738288)
# 2  SANDY HOOK, CT\n(41.419998, -73.282501)                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN  CT\n(41.575155, -72.738288)
#
# [5 rows x 32 columns]

# %%
df['Race'] = df.Race.replace({
    'Asian Indian': 'Asian',
    'Asian, Other': 'Asian',
    'Chinese': 'Asian',
    'Hawaiian': 'Other',
    'Unknown': 'Other',
    'Hispanic, Black': 'Hispanic',
    'Hispanic, White': 'Hispanic',
    'Native American, Other': 'Native American',
})

# %%
df.InjuryPlace.value_counts().head(30)
# Out:
# Residence                           3601
# Other                                269
# Residential Building                 241
# Hotel or Motel                       227
# Unknown                              176
# In Vehicle                            57
# Automobile                            46
# Other, Other Outdoor Area             42
# Parking Lot                           41
# Halfway House                         33
# House                                 25
# Restaurant                            19
# Apartment                             19
# Other indoor Area                     17
# Apartment House                       12
# Other, Public Buildings               11
# Other (unknown)                       10
# Nursing Home                          10
# Public Park                            9
# Driveway                               9
# Street                                 8
# Sidewalk                               8
# Forest, Wooded Area                    8
# Other, Park or Recreational Area       7
# Alleyway                               7
# Porch                                  7
# Yard                                   6
# Building                               6
# Other, Residential Institution         6
# Office Building                        6
# Name: InjuryPlace, dtype: int64

# %%
df['InjuryPlace'] = df.InjuryPlace.replace({
    'Automobile': 'In Vehicle',
    'Other, Other Outdoor Area': 'Outdoor Area',
    'Other, Public Buildings': 'Public Buildings',
    'Other (unknown)': 'Unknown',
    'Other, Park or Recreational Area': 'Park or Recreational Area',
})

# %%
df.head()
# Out:
#         ID          Date   Age     Sex   Race ResidenceCity  DeathCity  \
# 0  14-0273  6/28/14 0:00   NaN     NaN    NaN           NaN        NaN
# 1  13-0102  3/21/13 0:00  48.0    Male  Black       NORWALK    NORWALK
# 2  16-0165  3/13/16 0:00  30.0  Female  White    SANDY HOOK    DANBURY
# 3  16-0208  3/31/16 0:00  23.0    Male  White           RYE  GREENWICH
# 4  13-0052  2/13/13 0:00  22.0    Male  Asian      FLUSHING  GREENWICH
#
#    Location LocationifOther     DescriptionofInjury  ... Amphet Tramad  \
# 0       NaN             NaN               substance  ...    NaN    NaN
# 1  Hospital             NaN                     NaN  ...    NaN    NaN
# 2  Hospital             NaN         Substance Abuse  ...    NaN    NaN
# 3  Hospital             NaN         substance abuse  ...    NaN    NaN
# 4  Hospital             NaN  Transdermal Absorption  ...    NaN    NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid  \
# 0                NaN           NaN   NaN       NaN       NaN
# 1                NaN           NaN   NaN       NaN       NaN
# 2                NaN           NaN   NaN       NaN         Y
# 3                NaN           NaN   NaN       NaN         Y
# 4                NaN           NaN   NaN       NaN       NaN
#
#                              DeathCityGeo  \
# 0             CT\n(41.575155, -72.738288)
# 1     Norwalk, CT\n(41.11805, -73.412906)
# 2    Danbury, CT\n(41.393666, -73.451539)
# 3  Greenwich, CT\n(41.026526, -73.628549)
# 4  Greenwich, CT\n(41.026526, -73.628549)
#
#                           ResidenceCityGeo                InjuryCityGeo
# 0              CT\n(41.575155, -72.738288)  CT\n(41.575155, -72.738288)
# 1      NORWALK, CT\n(41.11805, -73.412906)  CT\n(41.575155, -72.738288)
# 2  SANDY HOOK, CT\n(41.419998, -73.282501)                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN  CT\n(41.575155, -72.738288)
#
# [5 rows x 32 columns]

# %%
df.InjuryPlace.value_counts()
# Out:
# Residence                         3601
# Other                              269
# Residential Building               241
# Hotel or Motel                     227
# Unknown                            186
# In Vehicle                         103
# Outdoor Area                        42
# Parking Lot                         41
# Halfway House                       33
# House                               25
# Restaurant                          19
# Apartment                           19
# Other indoor Area                   17
# Apartment House                     12
# Public Buildings                    11
# Nursing Home                        10
# Driveway                             9
# Public Park                          9
# Forest, Wooded Area                  8
# Street                               8
# Sidewalk                             8
# Park or Recreational Area            7
# Porch                                7
# Alleyway                             7
# Yard                                 6
# Hospital or Emergency Room           6
# Building                             6
# Office Building                      6
# Other, Residential Institution       6
# Store or Shopping Area               6
#                                   ...
# Stairs                               3
# Train or Subway Station              3
# Casino                               3
# Beach                                2
# Movie House or Theatre               2
# Detoxification Center                2
# Other, Health Care Facility          2
# Other, Industrial Area               2
# Railroad Track                       2
# Friend's Residence                   2
# Penal Institution                    2
# residence                            2
# University or College                2
# Warehouse                            2
# Cemetery                             2
# residential building                 1
# Church                               1
# Rest Home                            1
# Rehab House                          1
# Multiple Locations                   1
# car in hartford                      1
# Motel                                1
# Residential building                 1
# Convenience Store                    1
# River, Stream or Canal               1
# homeless shelter                     1
# Other, Farm or Ranch                 1
# Campgrounds                          1
# Shopping Center                      1
# School, Primary or Secondary         1
# Name: InjuryPlace, Length: 69, dtype: int64

# %%
df['InjuryPlace'] = df.InjuryPlace.replace({
    'Residential Building': 'Residence',
    'residential building': 'Residence',
    'House': 'Residence',
    'Other, Industrial Area': 'Indoor Area',
    'Other, Health Care Facility': 'Health Care Facility',
    'University or College': 'College Campus',
    'Apartment': 'Residence',
    'Driveway': 'Parking Lot',
    'Building': 'Public Buildings',
    'Other indoor Area': 'Indoor Area',
    'Forest, Wooded Area': 'Forest',
    'Park or Recreational Area': 'Public Park',
    'Hospital or Emergency Room': 'Hospital',
    'Sidewalk': 'Street',
    'Park': 'Public Park',
    'Store or Shopping Area': 'Store',
    'Other, Residential Institution': 'Residence',
    'Bar or Night Club': 'Bar',
    'Apartment House': 'Residence',
    'Shed': 'Garage',
    'Field': 'Outdoor Area',
    'Train or Subway Station': 'Train Station',
    'Roadway': 'Street',
    'car in hartford': 'In Vehicle',
    'Rest Home': 'Residence',
    'School, Primary or Secondary': 'School',
    'Other, Farm or Ranch': 'Farm',
    'Shopping Center': 'Store',
    'Motel': 'Hotel or Motel',
    'Public Park, Urban or Suburban': 'Public Park',
    'residence': 'Residence',
    'homeless shelter': 'Homeless Shelter',
    'Yard': 'Backyard',
    'Campgrounds': 'Outdoor Area',
    'Movie House or Theater': 'Movie Theatre'
    
    
})

# %%
df.to_csv('connecticutdrugs.csv')

# %%
df.head()
# Out:
#         ID          Date   Age     Sex   Race ResidenceCity  DeathCity  \
# 0  14-0273  6/28/14 0:00   NaN     NaN    NaN           NaN        NaN
# 1  13-0102  3/21/13 0:00  48.0    Male  Black       NORWALK    NORWALK
# 2  16-0165  3/13/16 0:00  30.0  Female  White    SANDY HOOK    DANBURY
# 3  16-0208  3/31/16 0:00  23.0    Male  White           RYE  GREENWICH
# 4  13-0052  2/13/13 0:00  22.0    Male  Asian      FLUSHING  GREENWICH
#
#    Location LocationifOther     DescriptionofInjury  ... Amphet Tramad  \
# 0       NaN             NaN               substance  ...    NaN    NaN
# 1  Hospital             NaN                     NaN  ...    NaN    NaN
# 2  Hospital             NaN         Substance Abuse  ...    NaN    NaN
# 3  Hospital             NaN         substance abuse  ...    NaN    NaN
# 4  Hospital             NaN  Transdermal Absorption  ...    NaN    NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid  \
# 0                NaN           NaN   NaN       NaN       NaN
# 1                NaN           NaN   NaN       NaN       NaN
# 2                NaN           NaN   NaN       NaN         Y
# 3                NaN           NaN   NaN       NaN         Y
# 4                NaN           NaN   NaN       NaN       NaN
#
#                              DeathCityGeo  \
# 0             CT\n(41.575155, -72.738288)
# 1     Norwalk, CT\n(41.11805, -73.412906)
# 2    Danbury, CT\n(41.393666, -73.451539)
# 3  Greenwich, CT\n(41.026526, -73.628549)
# 4  Greenwich, CT\n(41.026526, -73.628549)
#
#                           ResidenceCityGeo                InjuryCityGeo
# 0              CT\n(41.575155, -72.738288)  CT\n(41.575155, -72.738288)
# 1      NORWALK, CT\n(41.11805, -73.412906)  CT\n(41.575155, -72.738288)
# 2  SANDY HOOK, CT\n(41.419998, -73.282501)                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN  CT\n(41.575155, -72.738288)
#
# [5 rows x 32 columns]

# %%
df['DeathCity'].value_counts()
# Out:
# HARTFORD             563
# NEW HAVEN            374
# WATERBURY            368
# BRIDGEPORT           341
# NEW BRITAIN          227
# MERIDEN              145
# BRISTOL              144
# NORWICH              144
# NEW LONDON           137
# DANBURY              131
# TORRINGTON           114
# MANCHESTER           102
# MIDDLETOWN           100
# ENFIELD               81
# STAMFORD              76
# EAST HARTFORD         71
# MILFORD               70
# WEST HAVEN            69
# NORWALK               69
# DERBY                 65
# STRATFORD             55
# SOUTHINGTON           53
# WILLIMANTIC           51
# VERNON                48
# HAMDEN                46
# NEW MILFORD           44
# NAUGATUCK             42
# GROTON                42
# WALLINGFORD           36
# BRANFORD              35
#                     ...
# SPRAGUE                1
# ONECO                  1
# MORRIS                 1
# NORTH GRANBY           1
# GOSHEN                 1
# WESTON                 1
# BARKHAMSTED            1
# HAMPTON                1
# AMSTON                 1
# WEATOGUE               1
# BRIDGEWATER            1
# EAST HARTLAND          1
# KENT                   1
# HANOVER                1
# EAST CANAAN            1
# NORTH WINDAM           1
# STAFFORD SPGS          1
# BETHLEHEM              1
# BOZRAH                 1
# CORNWALL BRIDGE        1
# GROTON LONG POINT      1
# NORTH WINDHAM          1
# 6340                   1
# NORFOLK                1
# ROGERS                 1
# QUINEBAUG              1
# WASHINGTON             1
# POMFRET                1
# WAUREGAN               1
# LITCHFIELD             1
# Name: DeathCity, Length: 222, dtype: int64

# %%
hi = df[df.DeathCity.isin(['NEW HAVEN', 'BRIDGEPORT', 'HARTFORD', 'NEW BRITAIN', 'WATERBURY','MERIDEN', 'NORWICH',"BRISTOL", 'NEW LONDON', 'DANBURY'])]
#                           'TORRINGTON', 'MANCHESTER', 'MIDDLETOWN', 'ENFIELD', 'STAMFORD', 'EAST HARTFORD', 'MILFORD', 'WEST HAVEN', 'NORWALK', 'DERBY', 'STRATFORD', 'SOUTHINGTON', 'WILLIMANTIC', 'VERNON', 'HAMDEN', 'NEW MILFORD', 'NAUGATUCK', 'GROTON', 'WALLINGFORD', 'BRANFORD'])]

        
# fig, ax = plt.subplots(figsize=(20,20))
# chart = sns.swarmplot(ax=ax, x="DeathCity", y="Age", hue='Race',
#                       palette='Blues', size = 9, data=hi)

# plt.savefig("chart2.pdf")

fig, ax = plt.subplots(figsize=(12,9))
sns.boxenplot(ax=ax, x="DeathCity", y="Age",
              color="skyblue",
              scale="linear", data=hi)

plt.savefig("boxplot.pdf")

# %%
hi = df[df.InjuryPlace.isin(['Hotel or Motel', 'In Vehicle', 'Parking Lot', 'Halfway House', 'Restaurant', 'Public Buildings', "Nursing Home", 'Driveway', 'Public Park', 'Sidewalk'])]

source = hi

alt.Chart(source).mark_circle().encode(
    x='InjuryPlace',
    y='Date',
    size='count()'
)

# chart.save('chart.svg')

# %%
df2 = pd.read_csv("totaldeathsbyrace.csv")

# %%
df2.head
# Out:
# <bound method NDFrame.head of    year  total deaths  female  male  asian  black  hispanic  white  % female  \
# 0  2012           355      97   258      2     38        38    274      27.3
# 1  2013           490     140   350      2     44        52    388      28.6
# 2  2014           557     167   390      2     27        57    468      30.0
# 3  2015           726     190   536      3     46        79    593      26.2
# 4  2016           917     232   685      7     86       101    711      25.3
# 5  2017          1037     260   777      9     88       122    813      25.1
# 6  2018          1015     239   776      9    104       136    756      23.5
#
#    % male  % asian  % black  % hispanic  % white
# 0    72.7      0.6     10.7        10.7     77.2
# 1    71.4      0.4      9.0        10.6     79.2
# 2    70.0      0.4      4.8        10.2     84.0
# 3    73.8      0.4      6.3        10.9     81.7
# 4    74.7      0.8      9.4        11.0     77.5
# 5    74.9      0.9      8.5        11.8     78.4
# 6    76.5      0.9     10.2        13.4     74.5  >

# %%
df2.plot(x='year', 
         y=['% female', '% male'], 
         kind='barh', 
         figsize = (4,3),
         width=0.8,
         stacked=True)
plt.savefig('gender.pdf')

# %%
df2.plot(x='year', 
         y=['% black', 
            '% hispanic', 
            '% white',
            '% asian'], 
         kind='barh',
         figsize = (5,5),
         width=0.8,
         stacked=True)
plt.savefig('race2.pdf')

# %%
df2.plot(x='year', 
         y=['total deaths', 'female', 'male'], 
         kind='line',
         figsize = (4,3))
plt.savefig('deathsperyear.pdf')

# %%
df.DeathCity.value_counts()
# Out:
# HARTFORD             563
# NEW HAVEN            374
# WATERBURY            368
# BRIDGEPORT           341
# NEW BRITAIN          227
# MERIDEN              145
# BRISTOL              144
# NORWICH              144
# NEW LONDON           137
# DANBURY              131
# TORRINGTON           114
# MANCHESTER           102
# MIDDLETOWN           100
# ENFIELD               81
# STAMFORD              76
# EAST HARTFORD         71
# MILFORD               70
# WEST HAVEN            69
# NORWALK               69
# DERBY                 65
# STRATFORD             55
# SOUTHINGTON           53
# WILLIMANTIC           51
# VERNON                48
# HAMDEN                46
# NEW MILFORD           44
# NAUGATUCK             42
# GROTON                42
# WALLINGFORD           36
# BRANFORD              35
#                     ...
# SPRAGUE                1
# ONECO                  1
# MORRIS                 1
# NORTH GRANBY           1
# GOSHEN                 1
# WESTON                 1
# BARKHAMSTED            1
# HAMPTON                1
# AMSTON                 1
# WEATOGUE               1
# BRIDGEWATER            1
# EAST HARTLAND          1
# KENT                   1
# HANOVER                1
# EAST CANAAN            1
# NORTH WINDAM           1
# STAFFORD SPGS          1
# BETHLEHEM              1
# BOZRAH                 1
# CORNWALL BRIDGE        1
# GROTON LONG POINT      1
# NORTH WINDHAM          1
# 6340                   1
# NORFOLK                1
# ROGERS                 1
# QUINEBAUG              1
# WASHINGTON             1
# POMFRET                1
# WAUREGAN               1
# LITCHFIELD             1
# Name: DeathCity, Length: 222, dtype: int64

# %%
f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(x="Age", y="DeathCity", hue="Race",
              data=df, dodge=True, jitter=True,
              alpha=.25, zorder=1)

# Show the conditional means
sns.pointplot(x="Age", y="Sex", hue="Race",
              data=df, dodge=.532, join=False,
              markers="d", scale=.75, ci=None)

# Improve the legend 
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[3:], labels[3:], title="species",
          handletextpad=0, columnspacing=1,
          loc="lower right", ncol=3, frameon=True,
          color=colors.reshape(-1,4))

plt.savefig("cities.pdf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-34e8d6cc53bb> in <module>
#      10 sns.pointplot(x="Age", y="Sex", hue="Race",
#      11               data=df, dodge=.532, join=False,
# ---> 12               markers="d", scale=.75, ci=None)
#      13
#      14 # Improve the legend
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/seaborn/categorical.py in pointplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, ax, **kwargs)
#    3338         ax = plt.gca()
#    3339
# -> 3340     plotter.plot(ax)
#    3341     return ax
#    3342
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/seaborn/categorical.py in plot(self, ax)
#    1809     def plot(self, ax):
#    1810         """Make the plot."""
# -> 1811         self.draw_points(ax)
#    1812         self.annotate_axes(ax)
#    1813         if self.orient == "h":
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/seaborn/categorical.py in draw_points(self, ax)
#    1805                            c=point_colors, edgecolor=point_colors,
#    1806                            linewidth=mew, marker=marker, s=markersize,
# -> 1807                            zorder=z)
#    1808
#    1809     def plot(self, ax):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4488                 offsets=offsets,
#    4489                 transOffset=kwargs.pop('transform', self.transData),
# -> 4490                 alpha=alpha
#    4491                 )
#    4492         collection.set_transform(mtransforms.IdentityTransform())
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/matplotlib/collections.py in __init__(self, paths, sizes, **kwargs)
#     881         """
#     882
# --> 883         Collection.__init__(self, **kwargs)
#     884         self.set_paths(paths)
#     885         self.set_sizes(sizes)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/matplotlib/collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     126         self._hatch_color = mcolors.to_rgba(mpl.rcParams['hatch.color'])
#     127         self.set_facecolor(facecolors)
# --> 128         self.set_edgecolor(edgecolors)
#     129         self.set_linewidth(linewidths)
#     130         self.set_linestyle(linestyles)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/matplotlib/collections.py in set_edgecolor(self, c)
#     726         """
#     727         self._original_edgecolor = c
# --> 728         self._set_edgecolor(c)
#     729
#     730     def set_alpha(self, alpha):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/matplotlib/collections.py in _set_edgecolor(self, c)
#     710         except AttributeError:
#     711             pass
# --> 712         self._edgecolors = mcolors.to_rgba_array(c, self._alpha)
#     713         if set_hatch_color and len(self._edgecolors):
#     714             self._hatch_color = tuple(self._edgecolors[0])
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     284     result = np.empty((len(c), 4), float)
#     285     for i, cc in enumerate(c):
# --> 286         result[i] = to_rgba(cc, alpha)
#     287     return result
#     288
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     175         rgba = None
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#     179             _colors_full_map.cache[c, alpha] = rgba
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     236         # float)` and `np.array(...).astype(float)` all convert "0.5" to 0.5.
#     237         # Test dimensionality to reject single floats.
# --> 238         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     239     # Return a tuple to prevent the cached value from being modified.
#     240     c = tuple(c.astype(float))
#
# ValueError: Invalid RGBA argument: masked
